# %% [markdown]
# <a href="https://colab.research.google.com/github/mars241/NLP_Natural-Language-Processing/blob/main/Corrig%C3%A9_Th%C3%A9o_de_NLP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
no_sunshine= "Ain't no sunshine when she's gone. It's not warm when she's away. Ain't no sunshine when she's gone And she's always gone too long Anytime she's goes away Wonder this time where she's gone Wonder if she's gone to stay. Ain't no sunshine when she's gone. And this house just ain't no home Anytime she goes away. And I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know Hey I oughta leave young thing alone But ain't no sunshine when she's gone, woh woh. Ain't no sunshine when she's gone. Only darkness every day. Ain't no sunshine when she's gone And this house just ain't no home Anytime she goes away. Anytime she goes away Anytime she goes away Anytime she goes away"

# %% [markdown]
# mporte NLTK et télécharge les fonctions dont tu auras besoin (au fur et à mesure si nécessaire).
# Récupère le texte d'un article de presse de ton choix sur internet (en anglais ce sera plus simple, mais tu peux prendre la langue de ton choix). Affecte-le à une variable via un copier/coller dans ton notebook. Par simplicité pour la suite de cette quête, nous te conseillons de prendre un texte qui fait entre 10 et 30 lignes environ.
# Transforme ton texte en tokens de phrases
# Transforme ton texte en tokens de mots
# Compte la fréquence d'apparition de chaque mot et réalise un graphique (si possible un diagramme en barre) qui représente les 20 mots les plus présents dans ton texte. Y a-t-il beaucoup de mots qui te semblent être des stopwords ?
# Enlève les stop words et la ponctuation, et regarde à nouveau quels sont les mots les plus présents. Là encore, réalise le même graphique pour comparer.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.word_tokenize(no_sunshine)
# Out:
# ['Ai',
#  "n't",
#  'no',
#  'sunshine',
#  'when',
#  'she',
#  "'s",
#  'gone',
#  '.',
#  'It',
#  "'s",
#  'not',
#  'warm',
#  'when',
#  'she',
#  "'s",
#  'away',
#  '.',
#  'Ai',
#  "n't",
#  'no',
#  'sunshine',
#  'when',
#  'she',
#  "'s",
#  'gone',
#  'And',
#  'she',
#  "'s",
#  'always',
#  'gone',
#  'too',
#  'long',
#  'Anytime',
#  'she',
#  "'s",
#  'goes',
#  'away',
#  'Wonder',
#  'this',
#  'time',
#  'where',
#  'she',
#  "'s",
#  'gone',
#  'Wonder',
#  'if',
#  'she',
#  "'s",
#  'gone',
#  'to',
#  'stay',
#  '.',
#  'Ai',
#  "n't",
#  'no',
#  'sunshine',
#  'when',
#  'she',
#  "'s",
#  'gone',
#  '.',
#  'And',
#  'this',
#  'house',
#  'just',
#  'ai',
#  "n't",
#  'no',
#  'home',
#  'Anytime',
#  'she',
#  'goes',
#  'away',
#  '.',
#  'And',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
# ...

# %%
# coupé en phrase (c'est tt le texte car pas de ponctuation)
tokens_words= nltk.sent_tokenize(no_sunshine)
tokens_words
# Out:
# ["Ain't no sunshine when she's gone.",
#  "It's not warm when she's away.",
#  "Ain't no sunshine when she's gone And she's always gone too long Anytime she's goes away Wonder this time where she's gone Wonder if she's gone to stay.",
#  "Ain't no sunshine when she's gone.",
#  "And this house just ain't no home Anytime she goes away.",
#  "And I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know Hey I oughta leave young thing alone But ain't no sunshine when she's gone, woh woh.",
#  "Ain't no sunshine when she's gone Only darkness every day.",
#  "Ain't no sunshine when she's gone And this house just ain't no home Anytime she goes away.",
#  'Anytime she goes away Anytime she goes away Anytime she goes away']

# %%
mots= nltk.FreqDist(no_sunshine.split(" "))

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(mots)), list(mots.values()), align='center')
plt.xticks(range(len(mots)), list(mots.keys()), rotation=90)
plt.xlabel('Mots')
plt.ylabel('Fréquence')
plt.show()

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

nouveau_mots = {}
for mot, frequence in mots.items():
    if mot.lower() not in stop_words:
        nouveau_mots[mot] = frequence

print(nouveau_mots)
# Out:
# {"Ain't": 5, 'sunshine': 6, 'gone.': 2, 'warm': 1, 'away.': 3, 'gone': 6, 'always': 1, 'long': 1, 'Anytime': 6, 'goes': 6, 'away': 4, 'Wonder': 2, 'time': 1, 'stay.': 1, 'house': 2, "ain't": 3, 'home': 2, 'know,': 20, 'know': 6, 'Hey': 1, 'oughta': 1, 'leave': 1, 'young': 1, 'thing': 1, 'alone': 1, 'gone,': 1, 'woh': 1, 'woh.': 1, 'darkness': 1, 'every': 1, 'day.': 1}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(mots)), list(mots.values()), align='center')
plt.xticks(range(len(mots)), list(mots.keys()), rotation=90)
plt.xlabel('Mots')
plt.ylabel('Fréquence')
plt.show()

# %%
############################################# 2ND QUETE #################################
no_sunshine= "Ain't no sunshine when she's gone. It's not warm when she's away. Ain't no sunshine when she's gone And she's always gone too long Anytime she's goes away Wonder this time where she's gone Wonder if she's gone to stay. Ain't no sunshine when she's gone. And this house just ain't no home Anytime she goes away. And I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know, I know, I know, I know I know, I know Hey I oughta leave young thing alone But ain't no sunshine when she's gone, woh woh. Ain't no sunshine when she's gone. Only darkness every day. Ain't no sunshine when she's gone And this house just ain't no home Anytime she goes away. Anytime she goes away Anytime she goes away Anytime she goes away"

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
#je retire les ponctuations et je met en minuscule

tokens_words = " ".join(tokenizer.tokenize(no_sunshine))

tokens_words= tokens_words.lower()
tokens_words
# Out:
# 'ain t no sunshine when she s gone it s not warm when she s away ain t no sunshine when she s gone and she s always gone too long anytime she s goes away wonder this time where she s gone wonder if she s gone to stay ain t no sunshine when she s gone and this house just ain t no home anytime she goes away and i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know i know hey i oughta leave young thing alone but ain t no sunshine when she s gone woh woh ain t no sunshine when she s gone only darkness every day ain t no sunshine when she s gone and this house just ain t no home anytime she goes away anytime she goes away anytime she goes away anytime she goes away'

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist

stemmer = PorterStemmer()

stop_words = set(stopwords.words('english'))  #je retire les stopswords
no_sunshine_clean= " ".join(word for word in tokens_words.split() if word.lower() not in stop_words)
no_sunshine_clean
# Out:
# 'sunshine gone warm away sunshine gone always gone long anytime goes away wonder time gone wonder gone stay sunshine gone house home anytime goes away know know know know know know know know know know know know know know know know know know know know know know know know know know hey oughta leave young thing alone sunshine gone woh woh sunshine gone darkness every day sunshine gone house home anytime goes away anytime goes away anytime goes away anytime goes away'

# %%
from nltk.stem import SnowballStemmer
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Instancier le stemmer Snowball pour l'anglais
stemmer = SnowballStemmer("english")

#tokenisation
words = nltk.word_tokenize(no_sunshine_clean)
no_sunshine_stemmed = [stemmer.stem(word) for word in words]  #stemming des mots

stemmed_string = " ".join(no_sunshine_stemmed)  # Ici stemmage: réduire les mots à leur racine
stemmed_freq_dist = nltk.FreqDist(lemmatized_words)

stemmed_freq_dist
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# FreqDist({'know': 26, 'go': 15, 'away': 7, 'sunshine': 6, 'anytime': 6, 'wonder': 2, 'house': 2, 'home': 2, 'woh': 2, 'warm': 1, ...})

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(stemmed_freq_dist)), list(stemmed_freq_dist.values()), align='center')
plt.xticks(range(len(stemmed_freq_dist)), list(stemmed_freq_dist.keys()), rotation=90)
plt.xlabel('Mots')
plt.ylabel('Fréquence')
plt.show()

# %%
from nltk.stem import WordNetLemmatizer #ici lemmatisation (réduction de mots à leur forme de base )

nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]
lemmed_freq_dist=  nltk.FreqDist(lemmatized_words)
lemmed_freq_dist
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# FreqDist({'know': 26, 'go': 15, 'away': 7, 'sunshine': 6, 'anytime': 6, 'wonder': 2, 'house': 2, 'home': 2, 'woh': 2, 'warm': 1, ...})

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(lemmed_freq_dist)), list(lemmed_freq_dist.values()), align='center')
plt.xticks(range(len(lemmed_freq_dist)), list(lemmed_freq_dist.keys()), rotation=90)
plt.xlabel('Mots')
plt.ylabel('Fréquence')
plt.show()
