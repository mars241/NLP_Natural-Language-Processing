# %% [markdown]
# <a href="https://colab.research.google.com/github/mars241/NLP_Natural-Language-Processing/blob/main/AAM_WCS_NLP_3_WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🦾Challenge
# Tu vas reprendre ton notebook de la quête précédente, et réaliser 4 WordCloud différents :
#
# 1. Un WordCloud à partir du texte initial, grâce à la méthode generate_from_text
# 2. Un WordCloud grâce à la méthode generate_from_frequencies après nettoyage des stopwords et de la ponctuation.
# 3. Un WordCloud grâce à la méthode generate_from_frequencies après nettoyage des stopwords et de la ponctuation, et application d'un stemmer.
# 4. Un WordCloud grâce à la méthode generate_from_frequencies après nettoyage des stopwords et de la ponctuation, et application d'un lemmatizer.
# Partage le lien vers ton notebook en guise de solution au challenge.
#
# # Critères de validation
# Le notebook est consultable pour toute personne disposant du lien fourni par l'élève.
#
# Les 4 WordCloud sont présents.
#
# #Objectifs
# Dans cette quête, nous allons apprendre à représenter cela de manière graphique grâce au **WordCloud (nuage de mots)**.
#
# Tracer un WordCloud avec Python

# %%
# 0) Importer le NLTK en mode des "modules les plus classiques et les dictionnaires anglais"
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %% [markdown]
# 1. Un WordCloud à partir du texte initial, grâce à la méthode **generate_from_text**

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=480, height=480, max_font_size=200, min_font_size=10) # ici le paramètre de couleurs addictionel par défaut c'est le noir!;
# Sinon pour changer de couleur, ajouter ",background_color="white" " par exmple dans la variable wordcloud.

sentence = ('This is a story about dogs our canine pets Dogs are furry animals ! Ceci est une histoire de chiens nos animaux de compagnie. Les chiens sont des animaux à fourrure !')

# Génération du wordCloud depuis un texte avec la méthode "generate_from_text"
wordcloud.generate_from_text(sentence)

# Affichage grâce à Matplotlib
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# 2. Un WordCloud grâce à la méthode **generate_from_frequencies** après nettoyage des stopwords et de la ponctuation.

# %%
# Traitement du text originel (nettoyage des stopwords et de la ponctuation) et le sortir en liste de mot:
sentence = ('This is a story about dogs our canine pets Dogs are furry animals ! Ceci est une histoire de chiens nos animaux de compagnie. Les chiens sont des animaux à fourrure !')
sentence = sentence.lower() #Mettre minuscule


import string # Importer le module correspondant
#string.punctuation #  Pour afficher la liste des ponctuations visés
# Enlever la ponctuation
for punctuation in string.punctuation:
    sentence = sentence.replace(punctuation, ' ')

# Téléchargement du pakage stop word
nltk.download('stopwords')
# La bibliothèque des stops words en Anglais
from nltk.corpus import stopwords
# La bibliothèque de la tozennisation
from nltk.tokenize import word_tokenize

# Pour enlever les stops words des tokens en Anglais
tokens = nltk.word_tokenize(sentence)
tokens_clean = []
for words in tokens:
  if words not in nltk.corpus.stopwords.words("english"):
    tokens_clean.append(words)

tokens_clean
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['story',
#  'dogs',
#  'canine',
#  'pets',
#  'dogs',
#  'furry',
#  'animals',
#  'ceci',
#  'est',
#  'une',
#  'histoire',
#  'de',
#  'chiens',
#  'nos',
#  'animaux',
#  'de',
#  'compagnie',
#  'les',
#  'chiens',
#  'sont',
#  'des',
#  'animaux',
#  'à',
#  'fourrure']

# %%
# Créer le "WordCloud" après nettoyage des stopwords et de la ponctuation( à partir d'une liste de mots)
# Import du module de "WordCloud"
from wordcloud import WordCloud
# Génération du wordCloud depuis une liste de mots avec la méthode "generate_from_text" (joindre en text au préalable avec ".join")
string_tokens_clean = ' '.join(tokens_clean)
wordcloud.generate_from_text(string_tokens_clean)

# Affichage grâce à Matplotlib
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# 3. Un WordCloud grâce à la méthode **generate_from_frequencies** après nettoyage des stopwords et de la ponctuation, et application d'un **stemmer.**

# %%
# Il est rare la génération d'un "WordCloud" directe depuis un texte, car nous préférons créer un wordcloud après du processing.
# Nous avons donc souvent un dictionnaire de FreqDist.

# importer le module pour le "stemmer"
from nltk.stem import SnowballStemmer
# Nous pouvons maintenant faire un FreqDist sur cette nouvelle liste de tokens de la phrase complète :
full_vocab = nltk.FreqDist(tokens_clean)
full_vocab # ici full_vocab est le dictionnaire(FreqDist)

# importer le "wordcloud"
from wordcloud import WordCloud
# Génération du wordCloud depuis un texte avec la méthode "generate_from_frequencies" avec dictionnaire
wordcloud = wordcloud.generate_from_frequencies(full_vocab)

# Affichage grâce à Matplotlib
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# 4) Un WordCloud grâce à la méthode **generate_from_frequencies** après nettoyage des stopwords et de la ponctuation, et application d'un **lemmatizer**. Partage le lien vers ton notebook en guise de solution au challenge.

# %%
# traitrement du text originel (nettoyage des stopwords et de la ponctuation et application d'un lemmatizer)

sentence = ('This is a story about dogs our canine pets Dogs are furry animals ! Ceci est une histoire de chiens nos animaux de compagnie. Les chiens sont des animaux à fourrure !')
import string # Importer le module correspondant
# string.punctuation #  Pour afficher la liste des ponctuations visés
# Enlever la ponctuation
for punctuation in string.punctuation:
    sentence = sentence.replace(punctuation, ' ')

# import de la bibliothèque de tokenisation
from nltk.tokenize import word_tokenize
# tokenisation
# Pour enlever les stops words des tokens en Anglais
tokens = nltk.word_tokenize(sentence)
tokens_clean = [] # initialisation
for words in tokens:
  if words not in nltk.corpus.stopwords.words("english"):
    tokens_clean.append(words)
# ici "tokens_clean" est la liste de la "sentence" tokenizé, elle est remplie(.append) de tout les mots

# joindre en string la liste des mots tozénisés:
string_mots = ' '.join(tokens_clean)

#Lemmatizeration
import spacy
# Import des règles anglaises <=> correspond un "import spacy as nlp"
nlp = spacy.load('en_core_web_sm')

# spacy découpe automatiquement en tokens avec cette syntaxe :
sent_tokens = nlp(string_mots)

list_lemma = [] # initialisation
for token in sent_tokens:
  list_lemma.append(token.lemma_)
  print(token, token.lemma_)
# Out:
# This this
# story story
# dogs dog
# canine canine
# pets pet
# Dogs Dogs
# furry furry
# animals animal
# Ceci Ceci
# est e
# une une
# histoire histoire
# de de
# chiens chien
# nos nos
# animaux animaux
# de de
# compagnie compagnie
# Les Les
# chiens chien
# sont sont
# des des
# animaux animaux
# à à
# fourrure fourrure

# %%
# On applique les stop word à la liste Lemmatizée
mots_clean_stop = [i for i in list_lemma if not i in nltk.corpus.stopwords.words("english")]
# On reconstruit le texte avec les mots tozenisés et Lemmatizée:
paragraphe_clean_stop = ' '.join(mots_clean_stop)
paragraphe_clean_stop
# Out:
# 'story dog canine pet Dogs furry animal Ceci e une histoire de chien nos animaux de compagnie Les chien sont des animaux à fourrure'

# %%
## Affichage du "worldcloud" ##

# import de la bibliothèque du lemmatizer(spacy)
import spacy
# Import des règles anglaises
nlp = spacy.load('en_core_web_sm')


# Ici, nous repartons de notre lemmatizer spacy :

sent_tokens = nlp(paragraphe_clean_stop)

# / ! \ ici pour utiliser la méthode "generate_from_frequencies" avec un texte ("paragraphe_clean_stop") est caduc, il nous faut un dictionaire
# D'où la question: comment convertir le texte lemmatizé en dictionaire sans repartir du dictionaire de base fait avec le "FreqDist" ;> full_vocab = nltk.FreqDist(tokens_clean)
# D'autant que dans cette étape on a perdu la comptabilisation des mots(c_à_d les valeurs(= fréquence des mots) des clés(=mots))!

# Autre manière de "lemmatizé"
from nltk.stem import SnowballStemmer
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Instancier le stemmer Snowball pour l'anglais
stemmer = SnowballStemmer("english")

#tokenisation
words = nltk.word_tokenize(paragraphe_clean_stop)
full_vocab_stemmed = [stemmer.stem(word) for word in words]  #stemming des mots

# Ici stemmage: réduire les mots à leur racine et le ".join()" les regroupe en liste(une séquence modifiable de données ordonnées); donc on peut les comptabilisés
stemmed_string = " ".join(full_vocab_stemmed)
# Création du dictionnaire de fréquences
stemmed_freq_dist = nltk.FreqDist(full_vocab_stemmed)
# Affichage du "stemmed_freq_dist" qui est le DICO_LAMMENIZER_DES_FREQUENCES_A_METTRE DANS LE "generate_from_frequencies()"
stemmed_freq_dist

# Remarque:  Le dico semble dans nos attentes, prochaine étape génération du "WordCloud" !
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# FreqDist({'dog': 2, 'de': 2, 'chien': 2, 'animaux': 2, 'stori': 1, 'canin': 1, 'pet': 1, 'furri': 1, 'anim': 1, 'ceci': 1, ...})

# %%
# importer le "wordcloud"
from wordcloud import WordCloud # (A NOTER : la différence entre "wordcloud" & "WordCloud" !)

# Paramètrage du "wordcloud" à l'aide de la fct ".generate_from_frequencies"
wordcloud = wordcloud.generate_from_frequencies(stemmed_freq_dist)

# Affichage grâce à Matplotlib
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(wordcloud , interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
